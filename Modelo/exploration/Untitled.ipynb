# %%
import pandas as pd

pd.set_option('display.max_columns', None)

# %%
pedidos = pd.read_csv('orders_export_1.csv')

# %%
pedidos.head(10)
# Out:
#     Name                       Email Financial Status  \
# 0  #1029      rochipeluffo@gmail.com             paid
# 1  #1028  carolateresita73@gmail.com          pending
# 2  #1028  carolateresita73@gmail.com              NaN
# 3  #1028  carolateresita73@gmail.com              NaN
# 4  #1028  carolateresita73@gmail.com              NaN
# 5  #1027    julioforleo@yahoo.com.ar          pending
# 6  #1027    julioforleo@yahoo.com.ar              NaN
# 7  #1026     posseleonela5@gmail.com          pending
# 8  #1025     posseleonela5@gmail.com          pending
# 9  #1024  inesitagranero30@gmail.com             paid
#
#                      Paid at Fulfillment Status               Fulfilled at  \
# 0  2022-04-04 21:15:21 -0300        unfulfilled                        NaN
# 1                        NaN          fulfilled  2022-04-04 21:34:02 -0300
# 2                        NaN                NaN                        NaN
# 3                        NaN                NaN                        NaN
# 4                        NaN                NaN                        NaN
# 5                        NaN          fulfilled  2022-04-04 21:32:12 -0300
# 6                        NaN                NaN                        NaN
# 7                        NaN        unfulfilled                        NaN
# 8                        NaN          fulfilled  2022-04-04 21:26:44 -0300
# 9  2022-04-01 10:31:32 -0300        unfulfilled                        NaN
#
#   Accepts Marketing Currency  Subtotal  Shipping  Taxes    Total  \
# 0                no      ARS    2400.0       0.0    0.0   2400.0
# 1               yes      ARS   12470.0       0.0    0.0  12470.0
# 2               NaN      NaN       NaN       NaN    NaN      NaN
# 3               NaN      NaN       NaN       NaN    NaN      NaN
# 4               NaN      NaN       NaN       NaN    NaN      NaN
# 5               yes      ARS    8990.0       0.0    0.0   8990.0
# 6               NaN      NaN       NaN       NaN    NaN      NaN
# 7               yes      ARS    1600.0    1000.0    0.0   2600.0
# 8               yes      ARS    2600.0    1000.0    0.0   3600.0
# 9               yes      ARS    6390.0     664.0    0.0   7054.0
#
#    Discount Code  Discount Amount  \
# 0            NaN              0.0
# 1            NaN              0.0
# 2            NaN              NaN
# 3            NaN              NaN
# 4            NaN              NaN
# 5            NaN              0.0
# 6            NaN              NaN
# 7            NaN              0.0
# 8            NaN              0.0
# 9            NaN              0.0
#
#                                      Shipping Method  \
# 0  Loria 275, Lomas de Zamora, Provincia de Bueno...
# 1                                  Envio a Domicilio
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                  Envio a Domicilio
# 6                                                NaN
# 7                                  Envio a Domicilio
# 8                                  Envio a Domicilio
# 9                             Retiro en Sucursal OCA
#
#                   Created at  Lineitem quantity               Lineitem name  \
# 0  2022-04-04 21:15:20 -0300                  1   Serum Redensity. COLÁGENO
# 1  2022-04-04 19:39:48 -0300                  1              Kit Unisex Día
# 2  2022-04-04 19:39:48 -0300                  1                   Hydra Age
# 3  2022-04-04 19:39:48 -0300                  1                   BB. CREAM
# 4  2022-04-04 19:39:48 -0300                  1          Crema Antiage 360°
# 5  2022-04-04 10:04:14 -0300                  1                Rutina Noche
# 6  2022-04-04 10:04:14 -0300                  1  Sulderm Hydra Filler Light
# 7  2022-04-03 10:36:44 -0300                  1     Espuma de Limpieza 3en1
# 8  2022-04-03 10:33:49 -0300                  1  Sulderm Hydra Filler Light
# 9  2022-04-01 10:31:32 -0300                  1                Rutina Noche
#
#    Lineitem price  Lineitem compare at price  Lineitem sku  \
# 0          2400.0                        NaN           NaN
# 1          3870.0                     4800.0           NaN
# 2          3000.0                        NaN           NaN
# 3          2900.0                        NaN           NaN
# 4          2700.0                     3200.0           NaN
# 5          6390.0                     7600.0           NaN
# 6          2600.0                     3050.0           NaN
# 7          1600.0                        NaN           NaN
# 8          2600.0                     3050.0           NaN
# 9          6390.0                     7600.0           NaN
#
#    Lineitem requires shipping  Lineitem taxable Lineitem fulfillment status  \
# 0                        True              True                     pending
# 1                        True              True                   fulfilled
# 2                        True              True                   fulfilled
# 3                        True              True                   fulfilled
# 4                        True              True                   fulfilled
# 5                        True             False                   fulfilled
# 6                        True              True                   fulfilled
# 7                        True              True                     pending
# 8                        True              True                   fulfilled
# 9                        True             False                     pending
#
#            Billing Name                                     Billing Street  \
# 0             La Conchu                                     Cachimayo, 373
# 1      Carola Ostolaza                                  Dorrego 1456, 1457
# 2                   NaN                                                NaN
# 3                   NaN                                                NaN
# 4                   NaN                                                NaN
# 5  Constanza  Martinez   Ruta 192 192, B6708 Open Door, Provincia de Bu...
# 6                   NaN                                                NaN
# 7         Leonela Posse                       Calle Gral Pintos 191 3c, 3c
# 8         Leonela Posse                      Calle Gral Pintos 191 3c, 3c
# 9   María  Inés Granero                             Casa, Calle Alsina 446
#
#                                     Billing Address1  Billing Address2  \
# 0                                          Cachimayo               373
# 1                                       Dorrego 1456              1457
# 2                                                NaN               NaN
# 3                                                NaN               NaN
# 4                                                NaN               NaN
# 5  Ruta 192 192, B6708 Open Door, Provincia de Bu...             Uf644
# 6                                                NaN               NaN
# 7                           Calle Gral Pintos 191 3c                3c
# 8                           Calle Gral Pintos 191 3c               3c
# 9                                               Casa  Calle Alsina 446
#
#    Billing Company          Billing City Billing Zip Billing Province  \
# 0              NaN                  Caba       '1832                C
# 1              NaN           9 de julio        '6500                B
# 2              NaN                   NaN         NaN              NaN
# 3              NaN                   NaN         NaN              NaN
# 4              NaN                   NaN         NaN              NaN
# 5              NaN                Luján        '6708                B
# 6              NaN                   NaN         NaN              NaN
# 7              NaN             Chivilcoy    B6620KUC                B
# 8              NaN             Chivilcoy    B6620KUC                B
# 9              NaN  San Antonio De Areco       '2760                B
#
#   Billing Country  Billing Phone         Shipping Name  \
# 0              AR  015 3122-8557                   NaN
# 1              AR   2345 66-9533      Carola Ostolaza
# 2             NaN            NaN                   NaN
# 3             NaN            NaN                   NaN
# 4             NaN            NaN                   NaN
# 5              AR   11 4170-6612  Constanza  Martinez
# 6             NaN            NaN                   NaN
# 7              AR   2346 54-3011         Leonela Posse
# 8              AR   2346 54-3011         Leonela Posse
# 9              AR   11 6596-6565   María  Inés Granero
#
#                                      Shipping Street  \
# 0                                                NaN
# 1                                 Dorrego 1456, 1457
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5  Ruta 192 192, B6708 Open Door, Provincia de Bu...
# 6                                                NaN
# 7                       Calle Gral Pintos 191 3c, 3c
# 8                      Calle Gral Pintos 191 3c, 3c
# 9                             Casa, Calle Alsina 446
#
#                                    Shipping Address1 Shipping Address2  \
# 0                                                NaN               NaN
# 1                                       Dorrego 1456              1457
# 2                                                NaN               NaN
# 3                                                NaN               NaN
# 4                                                NaN               NaN
# 5  Ruta 192 192, B6708 Open Door, Provincia de Bu...             Uf644
# 6                                                NaN               NaN
# 7                           Calle Gral Pintos 191 3c                3c
# 8                           Calle Gral Pintos 191 3c               3c
# 9                                               Casa  Calle Alsina 446
#
#    Shipping Company         Shipping City Shipping Zip Shipping Province  \
# 0               NaN                   NaN          NaN               NaN
# 1               NaN           9 de julio         '6500                 B
# 2               NaN                   NaN          NaN               NaN
# 3               NaN                   NaN          NaN               NaN
# 4               NaN                   NaN          NaN               NaN
# 5               NaN                Luján         '6708                 B
# 6               NaN                   NaN          NaN               NaN
# 7               NaN             Chivilcoy     B6620KUC                 B
# 8               NaN             Chivilcoy     B6620KUC                 B
# 9               NaN  San Antonio De Areco        '2760                 B
#
#   Shipping Country Shipping Phone  Notes  Note Attributes  \
# 0              NaN            NaN    NaN              NaN
# 1               AR   2345 66-9533    NaN              NaN
# 2              NaN            NaN    NaN              NaN
# 3              NaN            NaN    NaN              NaN
# 4              NaN            NaN    NaN              NaN
# 5               AR   11 4170-6612    NaN              NaN
# 6              NaN            NaN    NaN              NaN
# 7               AR   2346 54-3011    NaN              NaN
# 8               AR   2346 54-3011    NaN              NaN
# 9               AR   11 6596-6565    NaN              NaN
#
#                 Cancelled at Payment Method  Payment Reference  \
# 0  2022-04-04 21:16:43 -0300   Mercado Pago  c22944765083799.1
# 1                        NaN   Bank Deposit                NaN
# 2                        NaN            NaN                NaN
# 3                        NaN            NaN                NaN
# 4                        NaN            NaN                NaN
# 5                        NaN   Mercado Pago                NaN
# 6                        NaN            NaN                NaN
# 7                        NaN   Mercado Pago                NaN
# 8                        NaN   Mercado Pago                NaN
# 9                        NaN   Mercado Pago  c22928337469591.1
#
#    Refunded Amount    Vendor            Id  Tags Risk Level Source  \
# 0              0.0  mishinpi  4.514587e+12   NaN        Low    web
# 1              0.0  mishinpi  4.514505e+12   NaN        Low    web
# 2              NaN  mishinpi           NaN   NaN        NaN    NaN
# 3              NaN  mishinpi           NaN   NaN        NaN    NaN
# 4              NaN  mishinpi           NaN   NaN        NaN    NaN
# 5              0.0  mishinpi  4.513795e+12   NaN        Low    web
# 6              NaN  midermis           NaN   NaN        NaN    NaN
# 7              0.0  mishinpi  4.512609e+12   NaN        Low    web
# 8              0.0  midermis  4.512606e+12   NaN        Low    web
# 9              0.0  mishinpi  4.509979e+12   NaN        Low    web
#
#    Lineitem discount Tax 1 Name  Tax 1 Value  Tax 2 Name  Tax 2 Value  \
# 0                0.0        NaN          NaN         NaN          NaN
# 1                0.0        NaN          NaN         NaN          NaN
# 2                0.0        NaN          NaN         NaN          NaN
# 3                0.0        NaN          NaN         NaN          NaN
# 4                0.0        NaN          NaN         NaN          NaN
# 5                0.0        NaN          NaN         NaN          NaN
# 6                0.0        NaN          NaN         NaN          NaN
# 7                0.0        NaN          NaN         NaN          NaN
# 8                0.0        NaN          NaN         NaN          NaN
# 9                0.0        NaN          NaN         NaN          NaN
#
#    Tax 3 Name  Tax 3 Value  Tax 4 Name  Tax 4 Value  Tax 5 Name  Tax 5 Value  \
# 0         NaN          NaN         NaN          NaN         NaN          NaN
# 1         NaN          NaN         NaN          NaN         NaN          NaN
# 2         NaN          NaN         NaN          NaN         NaN          NaN
# 3         NaN          NaN         NaN          NaN         NaN          NaN
# 4         NaN          NaN         NaN          NaN         NaN          NaN
# 5         NaN          NaN         NaN          NaN         NaN          NaN
# 6         NaN          NaN         NaN          NaN         NaN          NaN
# 7         NaN          NaN         NaN          NaN         NaN          NaN
# 8         NaN          NaN         NaN          NaN         NaN          NaN
# 9         NaN          NaN         NaN          NaN         NaN          NaN
#
#    Phone  Receipt Number  Duties            Billing Province Name  \
# 0    NaN             NaN     NaN  Ciudad Autónoma de Buenos Aires
# 1    NaN             NaN     NaN         Buenos Aires (provincia)
# 2    NaN             NaN     NaN                              NaN
# 3    NaN             NaN     NaN                              NaN
# 4    NaN             NaN     NaN                              NaN
# 5    NaN             NaN     NaN         Buenos Aires (provincia)
# 6    NaN             NaN     NaN                              NaN
# 7    NaN             NaN     NaN         Buenos Aires (provincia)
# 8    NaN             NaN     NaN         Buenos Aires (provincia)
# 9    NaN             NaN     NaN         Buenos Aires (provincia)
#
#      Shipping Province Name  Payment ID  Payment Terms Name  \
# 0                       NaN         NaN                 NaN
# 1  Buenos Aires (provincia)         NaN                 NaN
# 2                       NaN         NaN                 NaN
# 3                       NaN         NaN                 NaN
# 4                       NaN         NaN                 NaN
# 5  Buenos Aires (provincia)         NaN                 NaN
# 6                       NaN         NaN                 NaN
# 7  Buenos Aires (provincia)         NaN                 NaN
# 8  Buenos Aires (provincia)         NaN                 NaN
# 9  Buenos Aires (provincia)         NaN                 NaN
#
#    Next Payment Due At
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# 5                  NaN
# 6                  NaN
# 7                  NaN
# 8                  NaN
# 9                  NaN

# %%
pedidos.columns
# Out:
# Index(['Name', 'Email', 'Financial Status', 'Paid at', 'Fulfillment Status',
#        'Fulfilled at', 'Accepts Marketing', 'Currency', 'Subtotal', 'Shipping',
#        'Taxes', 'Total', 'Discount Code', 'Discount Amount', 'Shipping Method',
#        'Created at', 'Lineitem quantity', 'Lineitem name', 'Lineitem price',
#        'Lineitem compare at price', 'Lineitem sku',
#        'Lineitem requires shipping', 'Lineitem taxable',
#        'Lineitem fulfillment status', 'Billing Name', 'Billing Street',
#        'Billing Address1', 'Billing Address2', 'Billing Company',
#        'Billing City', 'Billing Zip', 'Billing Province', 'Billing Country',
#        'Billing Phone', 'Shipping Name', 'Shipping Street',
#        'Shipping Address1', 'Shipping Address2', 'Shipping Company',
#        'Shipping City', 'Shipping Zip', 'Shipping Province',
#        'Shipping Country', 'Shipping Phone', 'Notes', 'Note Attributes',
#        'Cancelled at', 'Payment Method', 'Payment Reference',
#        'Refunded Amount', 'Vendor', 'Id', 'Tags', 'Risk Level', 'Source',
#        'Lineitem discount', 'Tax 1 Name', 'Tax 1 Value', 'Tax 2 Name',
#        'Tax 2 Value', 'Tax 3 Name', 'Tax 3 Value', 'Tax 4 Name', 'Tax 4 Value',
#        'Tax 5 Name', 'Tax 5 Value', 'Phone', 'Receipt Number', 'Duties',
#        'Billing Province Name', 'Shipping Province Name', 'Payment ID',
#        'Payment Terms Name', 'Next Payment Due At'],
#       dtype='object')

# %%
important_columns = ['Name', 'Email', 'Subtotal', 'Shipping', 'Total', 'Discount Amount', 
 'Lineitem quantity', 'Lineitem name', 'Lineitem price', 'Lineitem compare at price', 'Lineitem sku', 
 'Lineitem requires shipping','Lineitem taxable', 'Lineitem fulfillment status',
 'Shipping Name', 'Shipping Street', 'Shipping Address1', 'Shipping Address2', 'Shipping Company',
 'Shipping City', 'Shipping Zip', 'Shipping Province', 'Shipping Country', 'Shipping Phone',
 'Lineitem discount', 'Billing Province Name', 'Shipping Province Name']

# %%
products_columns = ['Name', 'Lineitem quantity', 'Lineitem name',
 'Shipping Name', 'Shipping Street', 'Shipping Address1',
 'Shipping City', 'Shipping Zip', 'Shipping Province', 'Shipping Phone', 'Billing Province Name', 'Shipping Province Name']

# %%
pedidos[products_columns]
# Out:
#      Name  Lineitem quantity                        Lineitem name  \
# 0   #1029                  1            Serum Redensity. COLÁGENO
# 1   #1028                  1                       Kit Unisex Día
# 2   #1028                  1                            Hydra Age
# 3   #1028                  1                            BB. CREAM
# 4   #1028                  1                   Crema Antiage 360°
# 5   #1027                  1                         Rutina Noche
# 6   #1027                  1           Sulderm Hydra Filler Light
# 7   #1026                  1              Espuma de Limpieza 3en1
# 8   #1025                  1           Sulderm Hydra Filler Light
# 9   #1024                  1                         Rutina Noche
# 10  #1023                  1                            Hydra Age
# 11  #1022                  1        Protector Solar FPS50+ Facial
# 12  #1022                  1  Serum Hyaluronic. Filler HA + B5 B3
# 13  #1022                  1                  Agua Micelar 3 en 1
# 14  #1021                  1  Serum Hyaluronic. Filler HA + B5 B3
# 15  #1021                  2              Espuma de Limpieza 3en1
# 16  #1020                  1                            Hydra Age
# 17  #1020                  1  Serum Hyaluronic. Filler HA + B5 B3
# 18  #1019                  2                     Kit Rutina Noche
# 19  #1019                  2              Kit Diario + Protección
# 20  #1017                  1            Protector solar UVB + UVA
# 21  #1016                  1                       Kit Rutina Día
# 22  #1015                  1                            BB. CREAM
# 23  #1015                  1              Espuma de Limpieza 3en1
# 24  #1014                  1                            Hydra Age
# 25  #1013                  1  Serum Hyaluronic. Filler HA + B5 B3
# 26  #1012                  1  Serum Hyaluronic. Filler HA + B5 B3
# 27  #1011                  1                       Kit Rutina Día
# 28  #1010                  1                     Kit Rutina Noche
# 29  #1009                  1           Sulderm Hidra Filler Light
# 30  #1008                  1  Serum Hyaluronic. Filler HA + B5 B3
# 31  #1007                  1                  Agua Micelar 3 en 1
# 32  #1006                  1  Serum Hyaluronic. Filler HA + B5 B3
# 33  #1005                  1             Bolsas y Ojeras. Antiage
# 34  #1005                  1  Serum Hyaluronic. Filler HA + B5 B3
# 35  #1004                  1                  Agua Micelar 3 en 1
# 36  #1003                  1             Bolsas y Ojeras. Antiage
# 37  #1002                  1                   Crema Antiage 360°
# 38  #1002                  1             Bolsas y Ojeras. Antiage
#
#            Shipping Name                                    Shipping Street  \
# 0                    NaN                                                NaN
# 1       Carola Ostolaza                                  Dorrego 1456, 1457
# 2                    NaN                                                NaN
# 3                    NaN                                                NaN
# 4                    NaN                                                NaN
# 5   Constanza  Martinez   Ruta 192 192, B6708 Open Door, Provincia de Bu...
# 6                    NaN                                                NaN
# 7          Leonela Posse                       Calle Gral Pintos 191 3c, 3c
# 8          Leonela Posse                      Calle Gral Pintos 191 3c, 3c
# 9    María  Inés Granero                             Casa, Calle Alsina 446
# 10        Ramos Carolina                            JosÉ HernÁndez 1955, 51
# 11          Beatriz Auil                              Gelly 3375, Depto 13A
# 12                   NaN                                                NaN
# 13                   NaN                                                NaN
# 14          Beatriz Auil                              Gelly 3375, Depto 13A
# 15                   NaN                                                NaN
# 16                   NaN                                                NaN
# 17                   NaN                                                NaN
# 18                   NaN                                                NaN
# 19                   NaN                                                NaN
# 20                   NaN                                                NaN
# 21                   NaN                                                NaN
# 22         Venera Aldana                       Montevideo 20, Planta baja 7
# 23                   NaN                                                NaN
# 24                   NaN                                                NaN
# 25                   NaN                                                NaN
# 26      Antonela Demarco             14 de julio 10, Torre 2 piso 6 depto 4
# 27     Luciana  Miranda                               Acevedo 1589, 3A o 3C
# 28                   NaN                                                NaN
# 29                   NaN                                                NaN
# 30                   NaN                                                NaN
# 31                   NaN                                                NaN
# 32    Alejandra Kinsella                                 Paraguay 3534, 1 b
# 33     Maria Corinaldesi                                       Moreno 90, -
# 34                   NaN                                                NaN
# 35            La de Dora                                Cachimayo 373, Casa
# 36            La de Dora                                Cachimayo 373, Casa
# 37     La conchu de Dora                                Cachimayo 373, Casa
# 38                   NaN                                                NaN
#
#                                     Shipping Address1         Shipping City  \
# 0                                                 NaN                   NaN
# 1                                        Dorrego 1456           9 de julio
# 2                                                 NaN                   NaN
# 3                                                 NaN                   NaN
# 4                                                 NaN                   NaN
# 5   Ruta 192 192, B6708 Open Door, Provincia de Bu...                Luján
# 6                                                 NaN                   NaN
# 7                            Calle Gral Pintos 191 3c             Chivilcoy
# 8                            Calle Gral Pintos 191 3c             Chivilcoy
# 9                                                Casa  San Antonio De Areco
# 10                                JosÉ HernÁndez 1955       Capital Federal
# 11                                         Gelly 3375                  Caba
# 12                                                NaN                   NaN
# 13                                                NaN                   NaN
# 14                                         Gelly 3375                  Caba
# 15                                                NaN                   NaN
# 16                                                NaN                   NaN
# 17                                                NaN                   NaN
# 18                                                NaN                   NaN
# 19                                                NaN                   NaN
# 20                                                NaN                   NaN
# 21                                                NaN                   NaN
# 22                                      Montevideo 20               Mendoza
# 23                                                NaN                   NaN
# 24                                                NaN                   NaN
# 25                                                NaN                   NaN
# 26                                     14 de julio 10             Temperley
# 27                                       Acevedo 1589             Banfield
# 28                                                NaN                   NaN
# 29                                                NaN                   NaN
# 30                                                NaN                   NaN
# 31                                                NaN                   NaN
# 32                                      Paraguay 3534                  Caba
# 33                                          Moreno 90                 Colon
# 34                                                NaN                   NaN
# 35                                      Cachimayo 373                  CABA
# 36                                      Cachimayo 373                  CABA
# 37                                      Cachimayo 373                  CABA
# 38                                                NaN                   NaN
#
#    Shipping Zip Shipping Province     Shipping Phone  \
# 0           NaN               NaN                NaN
# 1         '6500                 B       2345 66-9533
# 2           NaN               NaN                NaN
# 3           NaN               NaN                NaN
# 4           NaN               NaN                NaN
# 5         '6708                 B       11 4170-6612
# 6           NaN               NaN                NaN
# 7      B6620KUC                 B       2346 54-3011
# 8      B6620KUC                 B       2346 54-3011
# 9         '2760                 B       11 6596-6565
# 10        '1426                 C       11 2797-7722
# 11        '1425                 C       11 3205-1593
# 12          NaN               NaN                NaN
# 13          NaN               NaN                NaN
# 14        '1425                 C       11 3205-1593
# 15          NaN               NaN                NaN
# 16          NaN               NaN                NaN
# 17          NaN               NaN                NaN
# 18          NaN               NaN                NaN
# 19          NaN               NaN                NaN
# 20          NaN               NaN                NaN
# 21          NaN               NaN                NaN
# 22        '5500                 M       221 531-6560
# 23          NaN               NaN                NaN
# 24          NaN               NaN                NaN
# 25          NaN               NaN                NaN
# 26        '1834                 B       11 3525-9565
# 27        '1828                 B       11 4027-7639
# 28          NaN               NaN                NaN
# 29          NaN               NaN                NaN
# 30          NaN               NaN                NaN
# 31          NaN               NaN                NaN
# 32        '1425                 C       15 5029-2075
# 33        '3280                 E       3447 43-5149
# 34          NaN               NaN                NaN
# 35        '1424                 C  '+54 11 6354-0969
# 36        '1424                 C  '+54 11 6354-0969
# 37        '1424                 C       11 6354-0969
# 38          NaN               NaN                NaN
#
#               Billing Province Name           Shipping Province Name
# 0   Ciudad Autónoma de Buenos Aires                              NaN
# 1          Buenos Aires (provincia)         Buenos Aires (provincia)
# 2                               NaN                              NaN
# 3                               NaN                              NaN
# 4                               NaN                              NaN
# 5          Buenos Aires (provincia)         Buenos Aires (provincia)
# 6                               NaN                              NaN
# 7          Buenos Aires (provincia)         Buenos Aires (provincia)
# 8          Buenos Aires (provincia)         Buenos Aires (provincia)
# 9          Buenos Aires (provincia)         Buenos Aires (provincia)
# 10  Ciudad Autónoma de Buenos Aires  Ciudad Autónoma de Buenos Aires
# 11  Ciudad Autónoma de Buenos Aires  Ciudad Autónoma de Buenos Aires
# 12                              NaN                              NaN
# 13                              NaN                              NaN
# 14  Ciudad Autónoma de Buenos Aires  Ciudad Autónoma de Buenos Aires
# 15                              NaN                              NaN
# 16         Buenos Aires (provincia)                              NaN
# 17                              NaN                              NaN
# 18         Buenos Aires (provincia)                              NaN
# 19                              NaN                              NaN
# 20         Buenos Aires (provincia)                              NaN
# 21         Buenos Aires (provincia)                              NaN
# 22                          Mendoza                          Mendoza
# 23                              NaN                              NaN
# 24         Buenos Aires (provincia)                              NaN
# 25         Buenos Aires (provincia)                              NaN
# 26         Buenos Aires (provincia)         Buenos Aires (provincia)
# 27         Buenos Aires (provincia)         Buenos Aires (provincia)
# 28                       Entre Ríos                              NaN
# 29         Buenos Aires (provincia)                              NaN
# 30         Buenos Aires (provincia)                              NaN
# 31         Buenos Aires (provincia)                              NaN
# 32  Ciudad Autónoma de Buenos Aires  Ciudad Autónoma de Buenos Aires
# 33                       Entre Ríos                       Entre Ríos
# 34                              NaN                              NaN
# 35  Ciudad Autónoma de Buenos Aires  Ciudad Autónoma de Buenos Aires
# 36  Ciudad Autónoma de Buenos Aires  Ciudad Autónoma de Buenos Aires
# 37  Ciudad Autónoma de Buenos Aires  Ciudad Autónoma de Buenos Aires
# 38                              NaN                              NaN
